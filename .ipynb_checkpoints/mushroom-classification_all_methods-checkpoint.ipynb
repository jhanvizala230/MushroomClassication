# %% [markdown]
# Hi, I'm going to apply 6 supervised machine learning classification models and an ANN model on the given dataset to classify mushrooms as poisonous or eatable.
# 1. Logistic Regression
# 2. Support Vector machines (SVC)
# 3. K-Nearest Neighbours(K-NN)
# 4. Naive Bayes classifier
# 5. Decision Tree Classifier
# 6. Random Forest Classifier
# 7. Artificial Neural Networks
#
# I'll proceed by converting categorical variables into dummy/indicator variables, then reducing dimensions using Princple Component Analysis to reduce 23 categorical variables (which will become 95 variables after conversion)
# to only 2 variables (Principle Components) and training different classification models over these two principle components. Finally, I'll visualize the outputs so that decision boundaries of different models can be seen in 2D-plane. Here the preference is not given to accuracy as the goal is to visualize the decision boundaries. For greater accuracy one can choose more than two variables.

# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np 
import pandas as pd
import warnings
warnings.simplefilter("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ### Importing the Dataset

# %%
dataset=pd.read_csv("./secondary_data.csv",sep = ';')
dataset.head()
# Out:
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
#
#   gill-attachment gill-spacing gill-color  stem-height  ...  stem-root  \
# 0               e          NaN          w        16.95  ...          s
# 1               e          NaN          w        17.99  ...          s
# 2               e          NaN          w        17.80  ...          s
# 3               e          NaN          w        15.77  ...          s
# 4               e          NaN          w        16.53  ...          s
#
#   stem-surface stem-color veil-type veil-color has-ring ring-type  \
# 0            y          w         u          w        t         g
# 1            y          w         u          w        t         g
# 2            y          w         u          w        t         g
# 3            y          w         u          w        t         p
# 4            y          w         u          w        t         p
#
#   spore-print-color habitat season
# 0               NaN       d      w
# 1               NaN       d      u
# 2               NaN       d      w
# 3               NaN       d      w
# 4               NaN       d      w
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Checking for nulls

# %%
dataset.isnull().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64

# %% [markdown]
# ### Description of Dataset

# %%
dataset.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %% [markdown]
# ### Encoding categorical data
# ### Label encoding

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder=LabelEncoder()
for column in dataset.columns:
    dataset[column] = labelencoder.fit_transform(dataset[column])

# %%
dataset.head()
# Out:
#    class  cap-diameter  cap-shape  cap-surface  cap-color  \
# 0      1          1481          6            2          6
# 1      1          1614          6            2          6
# 2      1          1362          6            2          6
# 3      1          1372          2            3          1
# 4      1          1419          6            3          6
#
#    does-bruise-or-bleed  gill-attachment  gill-spacing  gill-color  \
# 0                     0                2             3          10
# 1                     0                2             3          10
# 2                     0                2             3          10
# 3                     0                2             3          10
# 4                     0                2             3          10
#
#    stem-height  ...  stem-root  stem-surface  stem-color  veil-type  \
# 0         1577  ...          4             7          11          0
# 1         1681  ...          4             7          11          0
# 2         1662  ...          4             7          11          0
# 3         1463  ...          4             7          11          0
# 4         1537  ...          4             7          11          0
#
#    veil-color  has-ring  ring-type  spore-print-color  habitat  season
# 0           4         1          2                  7        0       3
# 1           4         1          2                  7        0       2
# 2           4         1          2                  7        0       3
# 3           4         1          5                  7        0       3
# 4           4         1          5                  7        0       3
#
# [5 rows x 21 columns]

# %% [markdown]
# # Poisonous = 1
# # Eatable = 0

# %%
plt.figure()
pd.Series(dataset['class']).value_counts().sort_index().plot(kind = 'bar')
plt.ylabel("Count")
plt.xlabel("class")
plt.title('Number of poisonous/edible mushrooms (0=edible, 1=poisonous)');

# %% [markdown]
# HeatMap for correlation

# %%
import seaborn as sns

plt.figure(figsize=(14,12))
sns.heatmap(dataset.corr(),linewidths=.1,cmap="YlGnBu", annot=True)
plt.yticks(rotation=0);

# %% [markdown]
# ### Class column is response and rest columns are predictors.
# ### Seprating Predictors and Response

# %%
X=dataset.drop('class',axis=1) #Predictors
y=dataset['class'] #Response
X.head()
# Out:
#    cap-diameter  cap-shape  cap-surface  cap-color  does-bruise-or-bleed  \
# 0          1481          6            2          6                     0
# 1          1614          6            2          6                     0
# 2          1362          6            2          6                     0
# 3          1372          2            3          1                     0
# 4          1419          6            3          6                     0
#
#    gill-attachment  gill-spacing  gill-color  stem-height  stem-width  \
# 0                2             3          10         1577        1656
# 1                2             3          10         1681        1766
# 2                2             3          10         1662        1721
# 3                2             3          10         1463        1545
# 4                2             3          10         1537        1667
#
#    stem-root  stem-surface  stem-color  veil-type  veil-color  has-ring  \
# 0          4             7          11          0           4         1
# 1          4             7          11          0           4         1
# 2          4             7          11          0           4         1
# 3          4             7          11          0           4         1
# 4          4             7          11          0           4         1
#
#    ring-type  spore-print-color  habitat  season
# 0          2                  7        0       3
# 1          2                  7        0       2
# 2          2                  7        0       3
# 3          5                  7        0       3
# 4          5                  7        0       3

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 61064    1
# 61065    1
# 61066    1
# 61067    1
# 61068    1
# Name: class, Length: 61069, dtype: int64

# %% [markdown]
# ### Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ### Applying PCA with  n_components = 10

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)

X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %% [markdown]
# ### Functions to visualize Training & Test Set Results.

# %%
def visualization_train(model):
    sns.set_context(context='notebook',font_scale=2)
    plt.figure(figsize=(10,5))
    from matplotlib.colors import ListedColormap
    X_set, y_set = X_train, y_train
    X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
    plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.6, cmap = ListedColormap(('red', 'green')))
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                    c = ListedColormap(('red', 'green'))(i), label = j)
    plt.title("%s Training Set" %(model))
    plt.xlabel('PC 1')
    plt.ylabel('PC 2')
    plt.legend()
def visualization_test(model):
    sns.set_context(context='notebook',font_scale=2)
    plt.figure(figsize=(10,5))
    from matplotlib.colors import ListedColormap
    X_set, y_set = X_test, y_test
    X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                         np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
    plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
                 alpha = 0.6, cmap = ListedColormap(('red', 'green')))
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                    c = ListedColormap(('red', 'green'))(i), label = j)
    plt.title("%s Test Set" %(model))
    plt.xlabel('PC 1')
    plt.ylabel('PC 2')
    plt.legend()

# %% [markdown]
# # Artificial Neural Networks (ANN)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# 2022-12-18 11:17:56.035519: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Initializing ANN

# %%
classifier = Sequential()
# Out:
# 2022-12-18 11:18:00.800273: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-18 11:18:00.802565: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# ## Adding Layers

# %%
classifier.add(Dense(8, kernel_initializer='uniform', activation= 'relu', input_dim = 10))
classifier.add(Dense(6, kernel_initializer='uniform', activation= 'relu'))
classifier.add(Dense(5, kernel_initializer='uniform', activation= 'relu'))
classifier.add(Dense(4, kernel_initializer='uniform', activation= 'relu'))
classifier.add(Dense(1, kernel_initializer='uniform', activation= 'sigmoid'))
classifier.compile(optimizer= 'adam',loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Fitting ANN to Training Set

# %%
classifier.fit(X_train,y_train,batch_size=50,epochs=300)
# Out:
# Epoch 1/300
# 855/855 [==============================] - 9s 10ms/step - loss: 0.6320 - accuracy: 0.6237
# Epoch 2/300
# 855/855 [==============================] - 10s 12ms/step - loss: 0.5376 - accuracy: 0.7162
# Epoch 3/300
# 855/855 [==============================] - 9s 10ms/step - loss: 0.4787 - accuracy: 0.7582
# Epoch 4/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4539 - accuracy: 0.7756
# Epoch 5/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4411 - accuracy: 0.7851
# Epoch 6/300
# 855/855 [==============================] - 6s 7ms/step - loss: 0.4326 - accuracy: 0.7904
# Epoch 7/300
# 855/855 [==============================] - 6s 7ms/step - loss: 0.4254 - accuracy: 0.7943
# Epoch 8/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4230 - accuracy: 0.7955
# Epoch 9/300
# 855/855 [==============================] - 6s 7ms/step - loss: 0.4196 - accuracy: 0.7974
# Epoch 10/300
# 855/855 [==============================] - 6s 7ms/step - loss: 0.4178 - accuracy: 0.7991
# Epoch 11/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4161 - accuracy: 0.8006
# Epoch 12/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4152 - accuracy: 0.8001
# Epoch 13/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4133 - accuracy: 0.8021
# Epoch 14/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4136 - accuracy: 0.8019
# Epoch 15/300
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4132 - accuracy: 0.8022
# Epoch 16/300
# 855/855 [==============================] - 6s 7ms/step - loss: 0.4127 - accuracy: 0.8028
# Epoch 17/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.4126 - accuracy: 0.8028
# Epoch 18/300
# 855/855 [==============================] - 9s 11ms/step - loss: 0.4114 - accuracy: 0.8036
# Epoch 19/300
# 855/855 [==============================] - 10s 11ms/step - loss: 0.4107 - accuracy: 0.8042
# Epoch 20/300
# 855/855 [==============================] - 9s 11ms/step - loss: 0.4094 - accuracy: 0.8055
# Epoch 21/300
# 855/855 [==============================] - 8s 10ms/step - loss: 0.4096 - accuracy: 0.8049
# Epoch 22/300
# 855/855 [==============================] - 9s 10ms/step - loss: 0.4084 - accuracy: 0.8064
# Epoch 23/300
# 855/855 [==============================] - 8s 10ms/step - loss: 0.4067 - accuracy: 0.8079
# Epoch 24/300
# 855/855 [==============================] - 9s 10ms/step - loss: 0.4069 - accuracy: 0.8071
# Epoch 25/300
# 855/855 [==============================] - 8s 10ms/step - loss: 0.4061 - accuracy: 0.8076
# Epoch 26/300
# 855/855 [==============================] - 9s 10ms/step - loss: 0.4043 - accuracy: 0.8088
# Epoch 27/300
# 855/855 [==============================] - 8s 9ms/step - loss: 0.4038 - accuracy: 0.8081
# Epoch 28/300
# 855/855 [==============================] - 8s 10ms/step - loss: 0.4038 - accuracy: 0.8090
# Epoch 29/300
# 855/855 [==============================] - 9s 10ms/step - loss: 0.4022 - accuracy: 0.8099
# Epoch 30/300
# 855/855 [==============================] - 8s 10ms/step - loss: 0.4016 - accuracy: 0.8107
# Epoch 31/300
# 855/855 [==============================] - 8s 10ms/step - loss: 0
300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.3514 - accuracy: 0.8465
# Epoch 298/300
# 855/855 [==============================] - 7s 8ms/step - loss: 0.3520 - accuracy: 0.8464
# Epoch 299/300
# 855/855 [==============================] - 8s 9ms/step - loss: 0.3516 - accuracy: 0.8464
# Epoch 300/300
# 855/855 [==============================] - 7s 9ms/step - loss: 0.3508 - accuracy: 0.8469

# %% [markdown]
# ## Predicting the Test Set Results

# %%
y_pred=classifier.predict(X_test)
y_pred=(y_pred>0.5)
# Out:
# 573/573 [==============================] - 5s 8ms/step

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix,classification_report
print(confusion_matrix(y_test, y_pred))
# Out:
# [[7968  140]
#  [2704 7509]]

# %% [markdown]
# ## Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.98      0.85      8108
#            1       0.98      0.74      0.84     10213
#
#     accuracy                           0.84     18321
#    macro avg       0.86      0.86      0.84     18321
# weighted avg       0.88      0.84      0.84     18321

# %% [markdown]
# ### Creating a func to evaluate model's performance.

# %%
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
def print_score(classifier,X_train,y_train,X_test,y_test,train=True):
    if train == True:
        print("Training results:\n")
        print('Accuracy Score: {0:.4f}\n'.format(accuracy_score(y_train,classifier.predict(X_train))))
        print('Classification Report:\n{}\n'.format(classification_report(y_train,classifier.predict(X_train))))
        print('Confusion Matrix:\n{}\n'.format(confusion_matrix(y_train,classifier.predict(X_train))))
        res = cross_val_score(classifier, X_train, y_train, cv=10, n_jobs=-1, scoring='accuracy')
        print('Average Accuracy:\t{0:.4f}\n'.format(res.mean()))
        print('Standard Deviation:\t{0:.4f}'.format(res.std()))
    elif train == False:
        print("Test results:\n")
        print('Accuracy Score: {0:.4f}\n'.format(accuracy_score(y_test,classifier.predict(X_test))))
        print('Classification Report:\n{}\n'.format(classification_report(y_test,classifier.predict(X_test))))
        print('Confusion Matrix:\n{}\n'.format(confusion_matrix(y_test,classifier.predict(X_test))))

# %% [markdown]
# # Logistic Regression Model
# ## Fitting Logistic Regression model to the Training set

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()

classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Logistic Regression Training Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 0.6132
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.41      0.49     19073
#            1       0.62      0.78      0.69     23675
#
#     accuracy                           0.61     42748
#    macro avg       0.61      0.59      0.59     42748
# weighted avg       0.61      0.61      0.60     42748
#
#
# Confusion Matrix:
# [[ 7820 11253]
#  [ 5284 18391]]
#
# Average Accuracy:	0.6133
#
# Standard Deviation:	0.0073

# %% [markdown]
# ## Logistic Regression Test Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=False)
# Out:
# Test results:
#
# Accuracy Score: 0.6178
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.42      0.49      8108
#            1       0.63      0.78      0.69     10213
#
#     accuracy                           0.62     18321
#    macro avg       0.61      0.60      0.59     18321
# weighted avg       0.61      0.62      0.60     18321
#
#
# Confusion Matrix:
# [[3381 4727]
#  [2275 7938]]

# %% [markdown]
# # Support Vecor (SVC) Classification Model
# ## Fitting SVC to the Training set

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='rbf',random_state=42)

classifier.fit(X_train,y_train)
# Out:
# SVC(random_state=42)

# %% [markdown]
# ## SVC Training Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 0.9653
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     19073
#            1       0.97      0.97      0.97     23675
#
#     accuracy                           0.97     42748
#    macro avg       0.97      0.96      0.96     42748
# weighted avg       0.97      0.97      0.97     42748
#
#
# Confusion Matrix:
# [[18271   802]
#  [  680 22995]]
#
# Average Accuracy:	0.9627
#
# Standard Deviation:	0.0049

# %% [markdown]
# ## SVC Test Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=False)
# Out:
# Test results:
#
# Accuracy Score: 0.9659
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      8108
#            1       0.97      0.97      0.97     10213
#
#     accuracy                           0.97     18321
#    macro avg       0.97      0.97      0.97     18321
# weighted avg       0.97      0.97      0.97     18321
#
#
# Confusion Matrix:
# [[7783  325]
#  [ 299 9914]]

# %% [markdown]
# # K Nearest Neighbors (K-NN) Classification Model
# ## Fitting K-NN to the Training set

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN

classifier = KNN(n_neighbors=11)
classifier.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %% [markdown]
# ## K-NN Training  Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 0.9987
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19073
#            1       1.00      1.00      1.00     23675
#
#     accuracy                           1.00     42748
#    macro avg       1.00      1.00      1.00     42748
# weighted avg       1.00      1.00      1.00     42748
#
#
# Confusion Matrix:
# [[19037    36]
#  [   21 23654]]
#
# Average Accuracy:	0.9977
#
# Standard Deviation:	0.0007

# %% [markdown]
# ## K-NN Test Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=False)
# Out:
# Test results:
#
# Accuracy Score: 0.9984
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8108
#            1       1.00      1.00      1.00     10213
#
#     accuracy                           1.00     18321
#    macro avg       1.00      1.00      1.00     18321
# weighted avg       1.00      1.00      1.00     18321
#
#
# Confusion Matrix:
# [[ 8088    20]
#  [   10 10203]]

# %% [markdown]
# # Naive Bayes Classification Model
# ## Fitting Naive Bayes classifier to the Training set

# %%
from sklearn.naive_bayes import GaussianNB as NB

classifier = NB()
classifier.fit(X_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ## Naive Bayes Training Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 0.6338
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.57      0.58     19073
#            1       0.66      0.69      0.68     23675
#
#     accuracy                           0.63     42748
#    macro avg       0.63      0.63      0.63     42748
# weighted avg       0.63      0.63      0.63     42748
#
#
# Confusion Matrix:
# [[10780  8293]
#  [ 7360 16315]]
#
# Average Accuracy:	0.6333
#
# Standard Deviation:	0.0058

# %% [markdown]
# ## Naive Bayes Test Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=False)
# Out:
# Test results:
#
# Accuracy Score: 0.6361
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.59      0.57      0.58      8108
#            1       0.67      0.69      0.68     10213
#
#     accuracy                           0.64     18321
#    macro avg       0.63      0.63      0.63     18321
# weighted avg       0.64      0.64      0.64     18321
#
#
# Confusion Matrix:
# [[4646 3462]
#  [3205 7008]]

# %% [markdown]
# # Decision Tree Classification Model
# ## Fitting Decision Tree classifier to the Training set

# %%
from sklearn.tree import DecisionTreeClassifier as DT

classifier = DT(criterion='entropy',random_state=42)
classifier.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=42)

# %% [markdown]
# ## Decision Tree Training Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19073
#            1       1.00      1.00      1.00     23675
#
#     accuracy                           1.00     42748
#    macro avg       1.00      1.00      1.00     42748
# weighted avg       1.00      1.00      1.00     42748
#
#
# Confusion Matrix:
# [[19073     0]
#  [    0 23675]]
#
# Average Accuracy:	0.9864
#
# Standard Deviation:	0.0018

# %% [markdown]
# ## Decision Tree Test Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=False)
# Out:
# Test results:
#
# Accuracy Score: 0.9862
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      8108
#            1       0.99      0.99      0.99     10213
#
#     accuracy                           0.99     18321
#    macro avg       0.99      0.99      0.99     18321
# weighted avg       0.99      0.99      0.99     18321
#
#
# Confusion Matrix:
# [[ 7983   125]
#  [  128 10085]]

# %% [markdown]
# # Random Forest Classification Model
# ## Fitting Random Forest classifier to the Training set

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 50, criterion = 'gini', random_state = 42)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=42)

# %% [markdown]
# ## Random Forest Training Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     19073
#            1       1.00      1.00      1.00     23675
#
#     accuracy                           1.00     42748
#    macro avg       1.00      1.00      1.00     42748
# weighted avg       1.00      1.00      1.00     42748
#
#
# Confusion Matrix:
# [[19073     0]
#  [    0 23675]]
#
# Average Accuracy:	0.9985
#
# Standard Deviation:	0.0007

# %% [markdown]
# ## Random Forest Test Results

# %%
print_score(classifier,X_train,y_train,X_test,y_test,train=False)
# Out:
# Test results:
#
# Accuracy Score: 0.9980
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      8108
#            1       1.00      1.00      1.00     10213
#
#     accuracy                           1.00     18321
#    macro avg       1.00      1.00      1.00     18321
# weighted avg       1.00      1.00      1.00     18321
#
#
# Confusion Matrix:
# [[ 8088    20]
#  [   17 10196]]

# %%
df = pd.DataFrame([['A', 10, 20, 10, 30], ['B', 20, 25, 15, 25], ['C', 12, 15, 19, 6],
                   ['D', 10, 29, 13, 19],['E', 10, 29, 13, 19],['F', 10, 29, 13, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4','Round5','Round6'])
# view data
print(df)
  
# plot grouped bar chart
df.plot(x='Team',
        kind='bar',
        stacked=False,
        title='Grouped Bar Graph with dataframe')
# Out:
#   Team  Round 1  Round 2  Round 3  Round 4
# 0    A       10       20       10       30
# 1    B       20       25       15       25
# 2    C       12       15       19        6
# 3    D       10       29       13       19
# <AxesSubplot: title={'center': 'Grouped Bar Graph with dataframe'}, xlabel='Team'>

# %% [markdown]
# # Results :
# | Classifier | ANN | Logistic Reg| SVC | K-NN | Naive Bayes | Decision Tree | Random Forest |
# | ---| --- | --- | --- | --- | --- | --- | --- |
# | Train accuracy score | | 0.6132 | 0.9289 | 0.9430 | 0.6338 | 1.00 | 1.00  |
# | Average accuracy score | | 0.6133 | 0.9281 | 0.9314 | 0.6333 | 0.9864 | 0.9986 |
# | Standard Deviation | | 0.0073 | 0.0112 | 0.0097 | 0.0058 | 0.0128 | 0.0018 |
# | Test accuary score | | 0.6178 | 0.9258 | 0.9307 | 0.64 | 0.99 | 1.00 |
